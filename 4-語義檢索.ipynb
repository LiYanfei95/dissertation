# %% [markdown]
# # 獲取句向量（需GPU，可租用GPU雲服務器）

# %%
from sentence_transformers import SentenceTransformer as SBert
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
import pandas as pd
import os
import pickle
import datasets

# 檢查是否可用GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SBert('./siku-bert').to(device)

# 數據集和列的相關信息
'''
數據集要求；CSV文件，文件名是語料的出處（例如書名），文件內其中有一列是書中的小片段（一般是句子），每句一行
'''
folder_path = "./output"
csv_column = '片段'  # 句子所在的列名

# 初始化存儲
all_data = pd.DataFrame()

# 遍歴文件夾中的所有文件併收集數據
file_map = {}
index = 0
for file in os.listdir(folder_path):
    if not file.endswith('.csv'):  # 跳過非 .csv 文件
        continue

    file_path = os.path.join(folder_path, file)
    file_name = os.path.splitext(file)[0]
    file_map[index] = file_name

    df = pd.read_csv(file_path)
    df['file_index'] = index
    all_data = pd.concat([all_data, df], ignore_index=True)
    index += 1

# 轉換爲datasets對象
dataset = datasets.Dataset.from_pandas(all_data)

# 創建數據加載器
batch_size = 10000

def collate_fn(batch):
    segments = [item[csv_column] for item in batch]
    return {csv_column: segments, 'file_index': [item['file_index'] for item in batch]}

dataloader = DataLoader(dataset, batch_size=batch_size, num_workers=160, shuffle=False, collate_fn=collate_fn)

# 獲取句子嵌入併顯示進度條
segments_embeddings = []
file_indices = []
with torch.no_grad(), tqdm(total=len(dataloader), desc='Processing') as pbar:
    for batch in dataloader:
        segments = batch[csv_column]
        encoded_segments = model.encode(segments, convert_to_tensor=True, device=device)
        segments_embeddings.append(encoded_segments)
        file_indices.extend(batch['file_index'])

        pbar.update(1)

# 合併所有嵌入向量
segments_embeddings = torch.cat(segments_embeddings, dim=0)

# 按文件索引保存嵌入向量
for idx, fname in file_map.items():
    output_path = os.path.join(folder_path, fname + '_segments_np.pkl')
    # 選擇同一文件索引的嵌入向量
    file_segments = segments_embeddings[torch.tensor(file_indices) == idx]
    segments_np = file_segments.cpu().numpy()

    # 保存爲Pickle文件
    with open(output_path, 'wb') as f:
        pickle.dump(segments_np, f)

# %% [markdown]
# # 在無GPU的本地機器上進行下一步處理

# %% [markdown]
# ##  數據庫連接

# %% [markdown]
# 需提前創建好以“yuliaoku”命名的數據庫，並創建Book表與Segment表。Book表有id、title字段，Segment表有id、text、vector（二進制類型）、book_id字段，其中book_id是外鍵。

# %%
from sqlalchemy import create_engine, Column, Integer, String, LargeBinary, ForeignKey
from sqlalchemy.orm import sessionmaker, relationship
from sqlalchemy.ext.declarative import declarative_base

mysql_user = 'root'
mysql_password = '' # 數據庫密碼
mysql_host = 'localhost'
mysql_port = '3306'
mysql_database = 'yuliaoku'


DATABASE_URL = f"mysql+pymysql://{mysql_user}:{mysql_password}@{mysql_host}:{mysql_port}/{mysql_database}"
engine = create_engine(DATABASE_URL)
Session = sessionmaker(bind=engine)
session = Session()

Base = declarative_base()

def create_book_class(table_name):
    class Book(Base):
        __tablename__ = table_name

        id = Column(Integer, primary_key=True)
        title = Column(String(80), nullable=False)

    return Book

def create_segment_class(book_table_name, segment_table_name):
    class Segment(Base):
        __tablename__ = segment_table_name

        id = Column(Integer, primary_key=True)
        text = Column(String(2000), nullable=True)
        vector = Column(LargeBinary, nullable=True)
        book_id = Column(Integer, ForeignKey(f'{book_table_name}.id'))

        book = relationship('Book')

    return Segment

part = 'fangyan'
book_table_name = f'book_{part}'
segment_table_name = f'segment_{part}'
Book = create_book_class(book_table_name)
Segment = create_segment_class(book_table_name, segment_table_name)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8576\2322973022.py:17: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %% [markdown]
# ## 將數據保存到MySQL中

# %%
import os
import pandas as pd
import numpy as np
import pickle

# 加載數據集和列的相關信息
data_folder = r'F:\data\output_fangyan'
csv_files = [file for file in os.listdir(data_folder) if file.endswith('.csv')]

# 書名和句子處理
for file in csv_files:
    csv_path = os.path.join(data_folder, file)
    book_name = file.replace('.csv', '')
    df = pd.read_csv(csv_path)

    # 查詢或插入書籍信息併獲取 book_id
    result = session.execute(f"SELECT id FROM {book_table_name} WHERE title = :book_name", {'book_name': book_name})
    book_id = result.fetchone() # 獲取查詢結果的第一條數據，這條數據是各字段的元組
    np_path = os.path.join(data_folder, book_name + '_segments_np.pkl')
    with open (np_path, 'rb') as f:
        segments_np = pickle.load(f)

    if book_id is None:
        session.execute(f"INSERT INTO {book_table_name} (title) VALUES (:book_name)", {'book_name': book_name})
        session.commit()
        result = session.execute(f"SELECT id FROM {book_table_name} WHERE title = :book_name", {'book_name': book_name})
        book_id = result.fetchone()[0]
    else:
        book_id = book_id[0]

    # 遍歴df行
    for index, row in df.iterrows():
        segment = row['片段']
        vector = pickle.dumps(segments_np[index])  # 將向量序列化爲二進制

        # 插入片段及其向量
        session.execute(f"INSERT INTO {segment_table_name} (text, vector, book_id) VALUES (:segment, :vector, :book_id)",
                        {'segment': segment, 'vector': vector, 'book_id': book_id})
    session.commit()

# %% [markdown]
# ## 構建索引

# %%
import faiss
import numpy as np
import pickle
import gc
from tqdm import tqdm

def build_faiss_index(index_file, ids_file, batch_size=10000):
    all_ids = []

    # 先確定向量維度
    example_segment = session.query(Segment).first()
    example_vector = pickle.loads(example_segment.vector)
    dimension = example_vector.shape[0]

    # 創建扁平索引
    index = faiss.IndexFlatIP(dimension)  # 使用內積來度量相似性

    count = session.query(Segment).count()
    print("開始處理：")
    for offset in tqdm(range(0, count, batch_size), desc="Indexing segments", total=count // batch_size + 1):
        segments = session.query(Segment).offset(offset).limit(batch_size).all()
        if not segments:
            continue

        vectors = np.stack([pickle.loads(segment.vector) for segment in segments]).astype(np.float32)
        ids = [segment.id for segment in segments]

        index.add(vectors)
        all_ids.extend(ids)

        # 清理變量以釋放內存，併執行垃圾回收
        del segments, vectors, ids
        gc.collect()

    # 保存faiss索引和ID到磁盤
    print("Saving index and ids to disk")
    faiss.write_index(index, index_file)
    with open(ids_file, 'wb') as f:
        pickle.dump(all_ids, f)

# 調用函數
index_file = r'F:\data\faiss_index_fangyan.bin'
ids_file = r'F:\data\ids_fangyan.pkl'
build_faiss_index(index_file, ids_file)

# %%
# 關閉數據庫會話
session.close()

# %% [markdown]
# ## 语义相似度查询

# %%
# 查詢前要連接數據庫，不用之後要關閉數據庫會話，避免佔據電腦資源

# %%
import torch
from sentence_transformers import SentenceTransformer as SBert
import faiss
import pickle
import numpy as np

# 加載模型
device = torch.device("cpu")
model_path = './siku-bert'
model = SBert(model_path).to(device)

# 加載faiss索引
index_file = f'F:/data/faiss_index_{part}.bin'
index = faiss.read_index(index_file) 

# 加載ids
ids_file = f'F:/data/ids_{part}.pkl'
with open(ids_file, 'rb') as f:
    ids = pickle.load(f)
# Out:
# No sentence-transformers model found with name ./siku-bert. Creating a new one with MEAN pooling.
# Some weights of BertModel were not initialized from the model checkpoint at ./siku-bert and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def search_query(model, index, session, Segment, Book, query_text: str, k: int = 50) -> None:
    # 查詢處理
    query_vector = model.encode([query_text])[0]
    D, I = index.search(np.array([query_vector]), k)

    # 根據Faiss索引獲取對應的數據庫ID
    matched_ids = [ids[i] for i in I[0]]

    # 構建查詢
    query = session.query(Segment, Book).join(Book).filter(Segment.id.in_(matched_ids))
    results_unsorted = query.all()

    # 將結果映射到ID
    id_to_results = {sentence.id: (sentence, book) for sentence, book in results_unsorted}

    # 輸出查詢結果
    for id in matched_ids:
        if id in id_to_results:
            sentence, book = id_to_results[id]
            print(f"{sentence.text}（《{book.title}》）")
            print("-" * 50)

# %%
k = 500
query_text = '山脊、山崗、山的最高處、山的連接處'
search_query(model, index, session, Segment, Book, query_text, k)
# Out:
# 山尖曰山頂、曰峯，山之宛下處曰山坳。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山之高者曰巒，尖起者曰峯。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 山崙曰峯。山道曰嶺。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 岡阜之高起如脊背者曰嶺，低伏有頂面者曰窪。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 定位頂尖上，謂山之巔、房屋樹木之高處也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山之高處曰坊塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山高處曰山頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山高處曰山頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 在山靠山，在水靠水。（《浙江省（中）》）
# --------------------------------------------------
# 突出處曰山包包。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 坟塔，小山相連峯起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 坡，肯靠。路，卡落。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 地理山之高者曰嶺、曰崖。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 平地有邱陵接近大山曰腦包，山半有窪塘接近平地曰山嘴。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 南山之根曰石灘。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 山下有平地曰坪子，稍低凹者曰窪子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山峯曰山尖尖，亦曰山顛顛，亦曰山頂頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山如削者曰崖，平者謂嶺。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# ，山寬平曰岡，陡峻曰崂，絶高曰峡。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山嶺曰坡，故上山曰上坡，再上曰高山，上不得曰陡微。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 培塔，小山相連峯起者之名。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山低處曰山窪窪。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山山相連峯起名曰蛇塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 屹塔，小山相連峯起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山嶺之平坦如鋪者曰坪，曰原上。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 民俗於地之高處亦多言堆，山曰山堆，嶺曰嶺堆，墳曰墳堆，草之和曰草堆，柴之積曰柴堆。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 坊琏山峯之回者，亦曰坊塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山崖岡嶺，不論高下皆曰坡。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 培塔，小山相連峯起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 培塔，小山相連峯起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 培塔，小山相連峯起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 丁一丫去尸尢上。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 稱山之有林木者爲山，無者爲嶺。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山之岡顛也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 堆石作山謂之山子石。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 堆石作山謂之山子石。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山山相連峯起名曰陽平塔力丫輕聲。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 上坡，衝堆。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 坊塔，物之高凸處也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 塔，阪地之平者曰塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 塔，阪地之平者曰塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山底下，謂黄龍山以南地；（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 高坡，碑巫的。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 高岡謂之航地，土高謂之为増，山腰平處謂之坪。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 人要心好，樹要根牢。（《浙江省（中）》）
# --------------------------------------------------
# 殿堂上最高處曰机棱。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 通呼高山曰嶺，平地曰堀，山曲曰增。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 注「尻，脊骨盡處，以山至高，其下必有託根之所也。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 坡之横長者曰坡境。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 坪山地之平者。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 坊塔，小山相連峯起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山麓曰山根。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 山麓曰山根。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 山尖突起曰峯，分水處曰崗，實即岡字，讀去聲。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 坊塔，小山相連峯起之名也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山，表。嶺，來上聲。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山頂謂之山頭。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山居升高處多級石階也。（《浙江省（上）》）
# --------------------------------------------------
# 圓山起尖頂曰蛇琏。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 蛇梁山脊之長者，又物之凸起而長者亦云然。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 兩山之間中忽低骂故名隆。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 呼屋之兩頭曰山頭。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 小山相連峯起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 高山，倒言曰山高，虚字在下也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山之高衅者曰幡。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 門縫裏的日頭，有一溜子，没一溜子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山之沿邊路曰後。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山腰之稍平者曰坪。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 汕暧羿山坳岡脊有通路者。（《浙江省（上）》）
# --------------------------------------------------
# 踰山有路低平者曰坳。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山之岡坡謂之弟。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 盤碗中盛飯菜太多曰骨累山尖，即魁壘山齊。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山嶺曰坡，故上山曰上坡，不可種者曰荒坡。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山嶺曰坡，故上山曰上坡，不可種者曰荒坡。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山小而高曰岑。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 其外至頂通稱崖背。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 石山有路者曰埔。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 山之過峽處曰山之窩處曰蛇塲。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 注云山頂即山頭也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 坡，肯靠。路，卡洛。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 踰山有路低平曰坳。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 踰山有路低平曰坳。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 釋山水山頂謂之山頭。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 坪山之平處。（《浙江省（上）》）
# --------------------------------------------------
# 坪，山地之平者曰坪。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 坪，山地之平者曰坪。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山之缺口曰嵐凹。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 如言頂頂好，頂爲頭之最上部，故以爲稱。（《浙江省（中）》）
# --------------------------------------------------
# 人都指着身子向上長。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 隔重肚皮隔重山。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 山脊曰山岡。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 蛇塔，小山相連烽起者之名。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 蛇凸，山間小阜曰蛇凸。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 大山，卡斜。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 山深入者曰山槌。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 土之高者曰墳。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 嵐坳謂山脊之田也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 稱物之上下曰浮頭與根底。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 釋地山頂謂之山頭。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 在山靠山水靠水，種豆得豆瓜得瓜。（《浙江省（中）》）
# --------------------------------------------------
# 謂左右有阻曰一邊是巖，一邊是坎。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 工丫去厂刃上。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 山寛平處曰黨黨。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山之平處曰坪坪。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 左手得來右手去，此山望見那山高。（《浙江省（中）》）
# --------------------------------------------------
# 出山謂屋之左右兩横邊盡頭處也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 出山謂屋之左右兩横邊盡頭處也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山之低下處或坡度，即窪字。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山之轉折處曰彎。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 高曰高長長。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 梁山脊爲梁。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 扒得高，跌得重。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 扒得高，跌得重。（《上海市、江蘇省》）
# --------------------------------------------------
# 扒得高，跌得重。（《上海市、江蘇省》）
# --------------------------------------------------
# 蛇塔，小山連起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山頂《韻英》「峯，山頂。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 前頭後頭所在之前爲前頭，所在之後爲後頭。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 西華處其中，又無大山嶺間隔。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 蜻兩山相接連處，每有小徑相通。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 兩頭尖。即路路通意。（《浙江省（上）》）
# --------------------------------------------------
# 土謂堆。巖謂頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 土謂堆。巖謂頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 自原至溝之路曰坡。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 阪地之平者。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 地類地之高聳者曰培塔，低下曰坑窩，平墉者曰展翅平，左右低而中起者曰魚脊梁。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 高山上添土。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 高山上添土。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 坡，迫。路，着底。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 天坍自有長人頂，橋倒壓不著差魚。（《浙江省（中）》）
# --------------------------------------------------
# 深山無人處曰古山峪表。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 表示出衆曰某處某事的頭等第一。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 自發石頭壓腳面，小船摇出大河江。（《浙江省（中）》）
# --------------------------------------------------
# 地類地之高聳者曰坊塔，低下者曰坑，又曰坊壻，平墉者曰展翅平，左右低而中起者曰蛇嶺。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 人向高處走，水向窪處流。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 四簷之各端及頂脊之兩端，共蹲六獸。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 嶺，來上聲。田，拏。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 窟窿凡山穴、牆隙、衣破處等，皆謂之窟窿。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 合的，合的是下。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 按指岡陵高處，或即塔，或即梁也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 高原曰山包。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 謂山半斜下處。（《浙江省（中）》）
# --------------------------------------------------
# 坳田謂旁窈下而中隆之高田也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 岳者，高峻之名。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 前船就是後船眼，後船就是爛船板。（《浙江省（中）》）
# --------------------------------------------------
# 謂地之突起礙行者曰坡。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 左右低而中有高路謂之魚脊梁。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 連山狹腰有路曰遼，紐要切。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 登山曰肥坡。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 峡峻，山之過峽處也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 峡峻，山之過峽處也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 岸曰嶺。上岸曰上嶺。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山峯之小而圓者。（《浙江省（上）》）
# --------------------------------------------------
# 山中低處曰蛆口。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山之平處。（《浙江省（上）》）
# --------------------------------------------------
# 峡峻，山之過狹處也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 媽坡翻湯三深中諸無岡必要時，可作一题。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 房，正也，屋之正大者也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 如低在地面曰塌地，鼻低者曰塌鼻頭，不高曰平塌塌。（《浙江省（中）》）
# --------------------------------------------------
# 地之高者曰梁，低者曰洼，寬者曰坪，狹者曰堰，凸者曰蛇堆，凹者曰埼洞。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 山謂之堆，堆形似山。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 屋最高處曰棟，下承之梁曰棟梁，餘曰屋梁。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 峯坪山尖突起，小而圓者曰山讀若炮。（《浙江省（上）》）
# --------------------------------------------------
# 如頂高、頂好之類。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 這山望着那山高，喻人妄想也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 崗，石倉區曰崑，山之分水也。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 龍頭牆角高聳者。（《浙江省（上）》）
# --------------------------------------------------
# 山之低下處也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 高頭境内西山一帶，名上邊曰高頭。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 自頂中而前，交於額上，卻繞紛也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 如最好曰頂好，最壊曰頂壊。（《浙江省（中）》）
# --------------------------------------------------
# 兩山之間有路謂之逕。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 兩山之間有路謂之逕。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 田在平原曰塲，在山頭曰界，在山邊曰塲。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山之岡坡皆謂之乡。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 兩山之間有路謂之逕，逕即隆與徑之通借。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 甬稱家宅曰頂宫，謂頭上之宫室也。（《浙江省（中）》）
# --------------------------------------------------
# 山崖曰崖頭。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 無惡不作，扳後腳，尋軋頭，占上風岸，打落馬威。（《浙江省（中）》）
# --------------------------------------------------
# 兩山間曰山槽槽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 手背是肉，手面也是肉。（《浙江省（中）》）
# --------------------------------------------------
# 曰天者，居人身最高部位也；（《浙江省（中）》）
# --------------------------------------------------
# 近肩之處曰上膊，近手之處曰下膊。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 近肩之處曰上膊，近手之處曰下膊。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 平地突起之小培瓊曰泥堆。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 筍在頭顛岀，花從褲帶挑。（《浙江省（中）》）
# --------------------------------------------------
# 脊骨盡處謂之腹。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 地稍下曰坎坎，稍高曰坡坡。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山頂白蠻謂之葱路。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 蛇搭，小山連起之名。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 梁，屋之正中也，故脊背亦曰梁。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 梁，屋之正中也，故脊背亦曰梁。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 为一尢上丁一丫去。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 只好高山望牢獄，弗好牢獄望高山。（《浙江省（中）》）
# --------------------------------------------------
# 人望高頭，水望低頭。（《浙江省（中）》）
# --------------------------------------------------
# 骨堆，土冢也。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 牆角高聳者曰籠頭。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 山半曰半坡上。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 高埠曰境。高崖曰吭。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 做好人，穴正冠客。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 上頂之階曰背台台。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山牆背後的柱子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 船之前曰尖子頭。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 遠而畢曰下。厂丫去。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 楼頭俗呼屋之兩頭曰山頭。（《上海市、江蘇省》）
# --------------------------------------------------
# 爲坂，山場爲隴，山隘爲碉，水口爲杏之類，與歪聿凸凹同一意義。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 世情天高不算高，人心節節高。（《浙江省（中）》）
# --------------------------------------------------
# 大後少丫去聲厂又去聲儿，即未來之第三日也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山曰巴。大山曰巴磽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山曰巴。大山曰巴磽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山曰巴。大山曰巴磽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 凡土石中有穴者皆曰。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 甬稱鼻之高起軟骨曰鼻頭樣，不數鼻翼而言亦有尊成兩目中間一小部分者。（《浙江省（中）》）
# --------------------------------------------------
# 加，马丫，馬紐線也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 田過水有沙石者曰沙灘，有土者曰淤泥。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 其不陡者曰一抹兒坡，較陡者曰珮坡子？（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 笆肩甲肩膀闊甬稱腋下曰肋夾肢下，謂肋骨與上肢相夾之處也。（《浙江省（中）》）
# --------------------------------------------------
# 俗呼圜而高者爲骨堆，特高者曰高骨堆，骨堆即崔嵬之倒語。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 只有加堆好，無没加堆貴。（《浙江省（中）》）
# --------------------------------------------------
# 培陀，地中大凹曰蛇陀。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 案蔽必曲，故甬稱背曲曰背脊高起之稱。（《浙江省（中）》）
# --------------------------------------------------
# 田過水有沙石者曰沙河灘，有土者曰淤泥坪。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 俗因稱從山腰斜超至地之風曰山脅風。（《浙江省（中）》）
# --------------------------------------------------
# 屋山頭開門。（《浙江省（中）》）
# --------------------------------------------------
# 埼嘴，山横如鳥喙者曰嘴，小者曰坊嘴。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山梁可通車馬處曰丫口，亦曰山口。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 如周家坑曰周丫坑，張家康家曰張丫康丫。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 腦後謂之腦勺子，其下謂之燕兒窩。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 如云弓的圖回的。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 即上彼挖搭累椎之山。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 甬稱山牆等高峻直立曰国，甚言其阱曰壁阱，謂如石壁之峻也。（《浙江省（中）》）
# --------------------------------------------------
# 兩物相比，高曰石，低曰潮。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 引伸之，凡物面上有低窪處，皆稱爲泊坑，或稱爲泊差。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 山之幽者曰凹，邑之南山有水泉凹、核桃凹是也。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 牛頭去了，拉了一根牛尾巴。（《浙江省（上）》）
# --------------------------------------------------
# 如崗好、崗香之類。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 山腰诉昭之坳。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 日没老雲接，明天把工歇。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 如棹子上邊曰棹子高頭。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 障，山脊也。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 向下，丁丫，方向也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山之缺口曰嵐境。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 人望高，水望低。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 人望高，水望低。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山頂霧謂罩子。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 嶺曰達坂。坡曰崖子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 均埸山崖之拐角處。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 當子腰，謂中間也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 嘴山横出一小尖如烏喙曰嘴。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 地方中間曰當中。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 大頭鬼頭大，飽刨刨好三包糕。（《浙江省（中）》）
# --------------------------------------------------
# 山：土高，地高，觸土，地岀頭，巫峯，老峙，登東，艮公，如礪，禹隨，一拳石。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 墳，地大也，幽凡土而高且大者謂之墳。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 上歇平，下遮。（《上海市、江蘇省》）
# --------------------------------------------------
# 上歇平，下遮。（《上海市、江蘇省》）
# --------------------------------------------------
# 上歇平，下遮。（《上海市、江蘇省》）
# --------------------------------------------------
# 上歇平，下遮。（《上海市、江蘇省》）
# --------------------------------------------------
# 上歇平，下遮。（《上海市、江蘇省》）
# --------------------------------------------------
# 山後下段語較重，其音近於激昂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 算出骨頭，兩個卵黄，數到大天亮。（《浙江省（中）》）
# --------------------------------------------------
# 已是一部位高而略前之〔。（《上海市、江蘇省》）
# --------------------------------------------------
# 在上曰高頭。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 上坡謂卡岑。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 上坡謂卡岑。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 上坡謂卡岑。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 上坡謂卡岑。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 水入土穴去他處也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 離頭牆角高聳者。（《浙江省（上）》）
# --------------------------------------------------
# 高埠曰埋。高崖曰吭。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 馬到，皆指積聚高大之物也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 腦在頭部，居重要位置。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山坡瓷石有步可行者曰踏步，亦曰踏道，凡上下有階級者皆同。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 土謂堆。燃謂頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 其最無倫脊者曰諸、曰胡。（《上海市、江蘇省》）
# --------------------------------------------------
# 培嘴，山横如鳥喙者曰嘴，小者曰坊嘴。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 塢山之深處。（《浙江省（上）》）
# --------------------------------------------------
# 塢山之深處。（《浙江省（上）》）
# --------------------------------------------------
# 孤墳配絶向，你蹺我突。（《浙江省（中）》）
# --------------------------------------------------
# 阿即窩也，言考槃於山之阿，即我之科座也。（《上海市、江蘇省》）
# --------------------------------------------------
# 战臨河兩岸高處之石路曰廷。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 阿教切。山顛曰腦。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 窪下之處曰乾灘。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 言身體第五頭。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 呼山脊爲梁。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 段玉裁注「沈彤《釋骨》曰顛之後，横起者曰頭横骨，曰枕骨，其兩旁尤起者，曰玉枕骨，即偃臥著枕之處。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 兩山峽道曰渠子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 放山，東邊各縣謂入山挖模曰放山。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 銷坑謂地面陷下之窟窿也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 朵者，木下垂，門堂伸出門之前後，略取其義。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 頭後曰後頸窩、後腦啄。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 地曰堆、曰第、曰底、曰羅。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 土謂堆。嚴謂頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 〔小路曰徑，山上小路曰雉鷄路。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 角落如牆縫等曰蛇裏培埠。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 斜上曰坡。溪曰溝。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 此處曰這裏，新併曰這坊塔。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山，波，的波。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 關曰卡子。寨曰寨子。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山鋭而長曰嶠。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 脊骨盡處謂之。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 謂山之峭立者曰由。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 與你去做賊，猗曰高每隘。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山坡地近溝處謂之溝坦，省作城。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 區域在某山之下者即名爲某山。（《浙江省（中）》）
# --------------------------------------------------
# 嶺曰塘。地曰堆。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 梁子謂連續之山嶺也，又謂仇釁也，又謂軍隊也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 峻嶂，山之過峽處也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 指他人而稱曰磴儂，磴，踞迴切。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 地類山之小者曰为塔，邑之南山有菜蛇塔村是也。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 嶄，山高峻貌。（《浙江省（中）》）
# --------------------------------------------------
# 後把啦，後面也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 四岸子，四周也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 二、地理山石奇突處曰础。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 石坳石堪，築石如台也。（《浙江省（上）》）
# --------------------------------------------------
# 丁山頭、眩下、謝家等處語之。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 後山黄泥要喫崩。（《浙江省（中）》）
# --------------------------------------------------
# 屋所對曰字向舉其全曰全向。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 樹根底下俗謂樹下曰樹根底下。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 山頂，户巴，娘泊。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山裏紅，山查。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 埔人統稱牙齒，當中曰當門牙，兩旁尖形的曰狗牙，大齒曰牙牀，齒下肉曰牙龈肉。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 平地下起埼堆。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山曰補。上山曰溜補。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山曰補。上山曰溜補。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 今謂堆積如山曰骨骨累累，即魁壘。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 凡物凸起者皆曰坊塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山，白，寨白里。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 關曰關口。寨曰寨子。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 如棹子上邊曰棹子膚頭。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 墩邑人謂高出地上之物爲墩，如云墩臺、土墩、石墩等。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 一把連曰連向子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 地中有物負土突起也。（《上海市、江蘇省》）
# --------------------------------------------------
# 人有千算天一算，各人頭上一方天。（《浙江省（中）》）
# --------------------------------------------------
# 疏「山節，刻柱頭爲斗拱形如山也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 以竹竿較短者，去细枝及葉留其大枝之斜上者，以支眼竿之兩端，謂之眼检杈。（《浙江省（中）》）
# --------------------------------------------------
# 庭内謂之坪，毗連謂之墳。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 坝，山之汙下也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 胳肋下者，脅骨之末，亦在腋下，故兼言之。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 推石自高而下曰磕。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 推石自高而下曰磕。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 推石自高而下曰磕。（《浙江省（上）》）
# --------------------------------------------------
# 即骨壘不平之土壤、骨壘不平之山。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 今俗凡積土而高者，皆曰骨堆。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 有一又拿方丫手尸又即有把握也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山上曰頂。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 山上曰頂。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 石曰論煙。山洞曰坑。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 石曰論煙。山洞曰坑。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 石曰論煙。山洞曰坑。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 屋角曰山頭。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 己去门丫上。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 坡狭獴謂之白陡，猴夷謂之料整，窩泥謂之戛打，卡惰謂之打一猫。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 峻山划土，一時即下。（《浙江省（中）》）
# --------------------------------------------------
# 如以指指某山以示人曰點山，拳術家以指指人要害之處曰點穴。（《浙江省（中）》）
# --------------------------------------------------
# 物之皺折不平者曰屹簇。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 坎肩謂之褂褂子，又謂之背心子。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 梁子謂連續之山嶺也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 險陵謂之陡。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 頂倒，看着也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 字一作要險，謂兩山之問，懸崖相對也。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 注「取物之上者，謂取物之顛也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 司枪者曰相公、梢公，在船頭者曰頭公。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 山帶霧曰山戴帽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 肚曰卡空。心曰卡秀。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 大山曰根得刀。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 大山曰根得刀。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 大山曰根得刀。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 大山曰根得刀。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 以肩挑兩木稍取水曰擔水。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 大漢，指身體高大者。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 蓋山嶺、建築物之位於地上，如人之坐於位也。（《浙江省（中）》）
# --------------------------------------------------
# 人物之高者謂之高佬，短者謂之喬仔。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 謂用鐵器刨挖，削去其土，並削斷餘根也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 謂用鐵器刨挖，削去其土，並削斷餘根也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 凡脊骨盡處皆尖，故又作腱。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 此服之凹陷處，正附近兩肩，故曰坎肩。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 地高平曰岡，廣平曰洋，下濕曰灣，微凹積水曰坷唐。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 山腳謂之山根。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山腳謂之山根。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 上壓肩頭，下磨腳底。（《浙江省（中）》）
# --------------------------------------------------
# 拔風謂出山處所載之木也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 人往高處走，水上窪處流。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 今俗謂肚之最厚處曰眩綱。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 有好多出被，出路也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 腿曰戛心。膝曰高窩。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 引伸凡物堆積者皆曰骨堆，亦曰疙瘩。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 陶注「此是腹大皮上多雅磊者。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 田螺延過太白山，上山容易下山難。（《浙江省（中）》）
# --------------------------------------------------
# 坊塔小山之回者曰培塔，亦曰塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 寨曰的巷。門曰勒丢。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 寨曰的巷。門曰勒丢。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 寨曰的巷。門曰勒丢。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 有地名曰門背腋，在西城，謂門之背後腋下也。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 住窜皆穴土崖而成，故室壁亦曰崖，其外即崖畔女弓去。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 堂，山寬平處也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 平原曰琪子，有水者曰海坂，亦曰田坂，沙泥多不成田地者曰沙坂。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 謂或在四方之山，或在五方之岳。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 凡土而高且大者，幽謂之墳。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 吊頸找大樹子。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 物之凸起而長者亦曰培梁。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 吃雷，從中上腰也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 甬稱領格曰個子，亦曰個子頭，如體格强壯曰個子頭結實，體格魁梧曰塊頭大，亦曰大塊頭。（《浙江省（中）》）
# --------------------------------------------------
# 自原至溝曰溝坡。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 为丫去安飞上。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 大前刃丫去聲一弓，即過去之第三日也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 吭頭地俗謂田上地也。（《上海市、江蘇省》）
# --------------------------------------------------
# 陡暨兩山夾出水處。（《浙江省（上）》）
# --------------------------------------------------
# 高處曰屹塔。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 擂推石自高而下曰擂。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 地曰堆。日曰頂。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山下受一南處。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 屋兩頭曰山牆。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 連綿不斷之土嶺曰涼。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 方書謂頂中央旋毛中爲百會，百會前一寸半爲前頂，百會前三寸即囱門。（《浙江省（中）》）
# --------------------------------------------------
# 立桅斗曰班首。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 道地大，垃圾多。（《浙江省（中）》）
# --------------------------------------------------
# 吃海，從中上腰也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 上有三十三重天，下有十八層地獄。（《浙江省（中）》）
# --------------------------------------------------
# 骨頭全無四兩重，好花能有幾時紅。（《浙江省（中）》）
# --------------------------------------------------
# 落乾没他人之物曰落，所没之物曰落頭。（《浙江省（上）》）
# --------------------------------------------------
# 住場在兩山之間，淺者曰沖，深者曰漕子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 棺前後之脉曰回頭。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 東蜀收句在後，語末曰歌、曰箇。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 挖牆曰拱窑子。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 要瞳山之過峽處。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 向日謂之陽坡，背謂之陰坡。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山頂霧曰山帶帽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山頂霧曰山帶帽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山頂霧曰山帶帽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 謂兩端高而中低曰鬼挑擔。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 虽大福大，樹大根大。（《浙江省（中）》）
# --------------------------------------------------
# 交人交强的，拄棍拄長的。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 土起岡陵曰坊塔。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 地線石分間作基石。（《浙江省（上）》）
# --------------------------------------------------
# 身體頭，農服，拱高。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 大山曰巴磽。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 山凹則曰山坳。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 土阜築牆曰寨子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 埋子謂嶺脊也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 絡頭，峭頭也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 跟頭筋斗也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 按孤垛與孤堆同義，砸孤垛，猶云就是這一堆也。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 山頭，屋旁也。（《上海市、江蘇省》）
# --------------------------------------------------
# 人多穴居，土穴曰土窜，石穴曰石窗。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 水頭猶言潮頭，故稱高潮曰大水頭，低潮曰小水頭。（《浙江省（中）》）
# --------------------------------------------------
# 子之少者曰儂，最小者曰細儂。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 子之少者曰儂，最小者曰細儂。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 九八丑地理及方所山之過峽處曰媛峻，即要險。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 打薩礎基下打莊木曰打碑。（《上海市、江蘇省》）
# --------------------------------------------------
# 背後多言曰谷東谷東。（《上海市、江蘇省》）
# --------------------------------------------------
# 山洞曰山窠子。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 山足即山根也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 山足即山根也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 土窪曰凹，土高曰凸。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 羊毛出在羊身上，鏤做搗臼舂。（《浙江省（中）》）
# --------------------------------------------------
# 炕之外端曰炕頭，裏端曰炕梢頭。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 又稱山嚴峻峭曰壁穩，謂如壁之直立也。（《浙江省（中）》）
# --------------------------------------------------
# 四旁盡處俗曰邊沿，亦曰邊沿頭。（《浙江省（中）》）
# --------------------------------------------------
# 有土窜、鑿土崖成洞。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 橋撑江，水帶，續斷，接引生。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 人從人上轧，刀從刀上磨。（《浙江省（中）》）
# --------------------------------------------------
# 溝地平坦者曰平川。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 火燒坡，呼姑挖西。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 行路拉後曰倆为一丫陽平下厂丫去聲。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 最大曰頂大。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 以磴合兩石，中琢縱横齒，碎物使成屑也。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 狭獰謂之峰出，獵夷謂之波，窩泥謂之为世所，卡惰謂之阿皮麻波。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 漸積起高曰堆堆。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 上赊亞切，尸丫，上下之上。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 石培凸、吴家城凸皆是。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 有穴謂之窟籠。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 有穴謂之窟籠。（《北京市、天津市、河北省》）
# --------------------------------------------------
# 夥人謂險峻曰棧，有羊棧嶺，即経字。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 山咋戴勝也。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 背，打軟，打浪，片骨。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 尸又上一丫。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 田過雲雨，眼睛等了望吊。（《浙江省（中）》）
# --------------------------------------------------
# 石紅有縫者曰紅石骨。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 又壘也，與寨同。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 坊凸，山間小阜曰培凸。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 帖窟近，是巖兩水也。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 雪，内。山，坡岂。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 娘有背後面前。（《浙江省（中）》）
# --------------------------------------------------
# 扯根眉毛下來比你腰桿粗。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 禮俗縣處複嶺疊川，方言凌雜，其不同之大界限，可以鍾水流域兩岸别之。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 没要緊，言非要事也。（《河北省（下）、山西省、內蒙古自治區、遼寧省、吉林省、黑龍江省》）
# --------------------------------------------------
# 三腿，上有小斗，下端安小绰，人摇而畜曳之。（《雲南省、西藏自治區、陝西省、甘肅省、青海省、寧夏回族自治區、新疆維吾爾自治區、臺灣省》）
# --------------------------------------------------
# 子之少者曰儂，其最小者細儂。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 度髙曰高。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 坳，音拗，兩山巔中凹處。（《浙江省（下）、安徽省、福建省、江西省》）
# --------------------------------------------------
# 子之小者曰儂，其最小者細儂兒。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 散處縣屬各區明山石山間，自爲部落。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 曰賊骨頭，輕賤者曰賤骨頭。（《浙江省（中）》）
# --------------------------------------------------
# 升於升，附一丫、乂丫於，附乂於五，附於世什。（《浙江省（上）》）
# --------------------------------------------------
# 堆積漸高曰堆堆。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 虫尢卩一丫为幺上力又上。（《山東省、河南省、湖北省、湖南省》）
# --------------------------------------------------
# 駝子背曲而若有臃腫者，如鸵之有峯也。（《浙江省（上）》）
# --------------------------------------------------
# 手掘物曰客，同挖。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 家給户由一紙，哥最下，秀最上。（《廣東省、廣西壯族自治區、海南省》）
# --------------------------------------------------
# 挖耳曰山挖耳。（《重慶市、貴州省、四川省》）
# --------------------------------------------------
# 挖耳曰山挖耳。（《重慶市、貴州省、四川省》）
# --------------------------------------------------

# %%
# 關閉數據庫會話
session.close()
